# %% [markdown]
# # Lecture 3: Introduction to Pandas

# %% [markdown]
# ## Connecting to the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import DF

# %%
import pandas as pd

# %% [markdown]
# ## Import a data and explore it

# %%
df= pd.read_csv('/content/drive/MyDrive/Preply/Mariia/Data/Employees_1.csv')

# %%
df
# Out:
#    ID               EMP       PAY Gender
# 0  11      Jack Johnson   20000.0      M
# 1  33       Karim Hikal  110000.0      M
# 2  12   Sonia Chiarelli   88000.0      F
# 3  22    Roberta Taylor       NaN      F
# 4  30   Stepan Zairovic   90000.0      M
# 5   2     Samir Guliyev  100000.0      M
# 6  21     Kurt Hartmann   90000.0      M
# 7  19        Imran Khan   70000.0      M
# 8   9  Lorenzo Chillini   66000.0      M
# 9  21     Kurt Hartmann   90000.0      M

# %%
df.head()
# Out:
#    ID              EMP       PAY Gender
# 0  11     Jack Johnson   20000.0      M
# 1  33      Karim Hikal  110000.0      M
# 2  12  Sonia Chiarelli   88000.0      F
# 3  22   Roberta Taylor       NaN      F
# 4  30  Stepan Zairovic   90000.0      M

# %% [markdown]
# You can also select the number of the rows to show by adding the number into head(number) function. Ex. head(10)

# %%
#Show ten first rows in dataset

# %%
df.describe()
# Out:
#               ID            PAY
# count  10.000000       9.000000
# mean   18.000000   80444.444444
# std     9.580072   26358.637631
# min     2.000000   20000.000000
# 25%    11.250000   70000.000000
# 50%    20.000000   90000.000000
# 75%    21.750000   90000.000000
# max    33.000000  110000.000000

# %% [markdown]
# For categorical variables you can use value_counts() function

# %%
df[['Gender']].value_counts()
# Out:
# Gender
# M         8
# F         2
# dtype: int64

# %% [markdown]
# In order to show it as a frame you apply at the end to_frame()

# %%
df['Gender'].value_counts().to_frame()
# Out:
#    Gender
# M       8
# F       2

# %% [markdown]
# ## Select a column

# %%
df[['EMP']]
# Out:
#                 EMP
# 0      Jack Johnson
# 1       Karim Hikal
# 2   Sonia Chiarelli
# 3    Roberta Taylor
# 4   Stepan Zairovic
# 5     Samir Guliyev
# 6     Kurt Hartmann
# 7        Imran Khan
# 8  Lorenzo Chillini
# 9     Kurt Hartmann

# %%
#Select a column with salaries

# %%
df[['EMP','PAY']]
# Out:
#                 EMP       PAY
# 0      Jack Johnson   20000.0
# 1       Karim Hikal  110000.0
# 2   Sonia Chiarelli   88000.0
# 3    Roberta Taylor       NaN
# 4   Stepan Zairovic   90000.0
# 5     Samir Guliyev  100000.0
# 6     Kurt Hartmann   90000.0
# 7        Imran Khan   70000.0
# 8  Lorenzo Chillini   66000.0
# 9     Kurt Hartmann   90000.0

# %%
type(df['EMP'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Conditional Selection

# %%
df[df['PAY'] > 80000] #Attention if you do this you will have en error df[df[['PAY']] > 50000]
# Out:
#    ID              EMP       PAY Gender
# 1  33      Karim Hikal  110000.0      M
# 2  12  Sonia Chiarelli   88000.0      F
# 4  30  Stepan Zairovic   90000.0      M
# 5   2    Samir Guliyev  100000.0      M
# 6  21    Kurt Hartmann   90000.0      M
# 9  21    Kurt Hartmann   90000.0      M

# %%
df[df['EMP'].str.contains('Kurt')]
# Out:
#    ID            EMP      PAY Gender
# 6  21  Kurt Hartmann  90000.0      M
# 9  21  Kurt Hartmann  90000.0      M

# %%
df[df[['PAY']] > 50000]  #Attention if you do this you will have en error
# Out:
#    ID  EMP       PAY Gender
# 0 NaN  NaN       NaN    NaN
# 1 NaN  NaN  110000.0    NaN
# 2 NaN  NaN   88000.0    NaN
# 3 NaN  NaN       NaN    NaN
# 4 NaN  NaN   90000.0    NaN
# 5 NaN  NaN  100000.0    NaN
# 6 NaN  NaN   90000.0    NaN
# 7 NaN  NaN   70000.0    NaN
# 8 NaN  NaN   66000.0    NaN
# 9 NaN  NaN   90000.0    NaN

# %% [markdown]
# Select **female** workers which have the salary of **>50k**

# %%
df[(df['PAY'] > 50000) & (df['Gender']=="F")] # AND operator in PANDAS is used as & and OR like |
# Out:
#    ID              EMP      PAY Gender
# 2  12  Sonia Chiarelli  88000.0      F

# %%
df[(df['PAY'] > 50000) | (df['Gender']=="F")] # AND operator in PANDAS is used as & and OR like |
# Out:
#    ID               EMP       PAY Gender
# 1  33       Karim Hikal  110000.0      M
# 2  12   Sonia Chiarelli   88000.0      F
# 3  22    Roberta Taylor       NaN      F
# 4  30   Stepan Zairovic   90000.0      M
# 5   2     Samir Guliyev  100000.0      M
# 6  21     Kurt Hartmann   90000.0      M
# 7  19        Imran Khan   70000.0      M
# 8   9  Lorenzo Chillini   66000.0      M
# 9  21     Kurt Hartmann   90000.0      M

# %%
# Find workers with a salary higher than 100k or lower than 50k

# %% [markdown]
# ### If you are interested in difference between df[['PAY']] and df['PAY']

# %%
series = df['PAY']
type(series)
# Out:
# pandas.core.series.Series

# %%
dataframe = df[['PAY']]
type(series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Select 2 columns

# %% [markdown]
# ## Spot the null

# %%
df.isnull().sum()
# Out:
# ID        0
# EMP       0
# PAY       1
# Gender    0
# dtype: int64

# %% [markdown]
# ### Drop the null

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# ID        0
# EMP       0
# PAY       0
# Gender    0
# dtype: int64

# %% [markdown]
# ## We got new list of employees! But wait!!!
# The File doesn't doesn't work correctly!

# %%
df2= pd.read_csv('/content/drive/MyDrive/Preply/Mariia/Data/Employees_2.csv')

# %%
df2
# Out:
#                ID;EMP;PAY;Gender
# 0          19;Imran Khan;70000;M
# 1  72;Maria Ibrahimovic;120000;F
# 2        88;Steve Jobs;1000000;M

# %%
df2= pd.read_csv('/content/drive/MyDrive/Preply/Mariia/Data/Employees_2.csv', sep = ";")

# %%
df2.head()
# Out:
#    ID                EMP      PAY Gender
# 0  19         Imran Khan    70000      M
# 1  72  Maria Ibrahimovic   120000      F
# 2  88         Steve Jobs  1000000      M

# %% [markdown]
# ## Unite 2 files now

# %%
df3= pd.concat([df,df2],axis=0)

# %%
df3
# Out:
#    ID                EMP        PAY Gender
# 0  11       Jack Johnson    20000.0      M
# 1  33        Karim Hikal   110000.0      M
# 2  12    Sonia Chiarelli    88000.0      F
# 4  30    Stepan Zairovic    90000.0      M
# 5   2      Samir Guliyev   100000.0      M
# 6  21      Kurt Hartmann    90000.0      M
# 7  19         Imran Khan    70000.0      M
# 8   9   Lorenzo Chillini    66000.0      M
# 9  21      Kurt Hartmann    90000.0      M
# 0  19         Imran Khan    70000.0      M
# 1  72  Maria Ibrahimovic   120000.0      F
# 2  88         Steve Jobs  1000000.0      M

# %% [markdown]
# ### Reseting index

# %%
df3 = df3.reset_index(drop=True)

# %%
df3
# Out:
#     ID                EMP        PAY Gender
# 0   11       Jack Johnson    20000.0      M
# 1   33        Karim Hikal   110000.0      M
# 2   12    Sonia Chiarelli    88000.0      F
# 3   30    Stepan Zairovic    90000.0      M
# 4    2      Samir Guliyev   100000.0      M
# 5   21      Kurt Hartmann    90000.0      M
# 6   19         Imran Khan    70000.0      M
# 7    9   Lorenzo Chillini    66000.0      M
# 8   21      Kurt Hartmann    90000.0      M
# 9   19         Imran Khan    70000.0      M
# 10  72  Maria Ibrahimovic   120000.0      F
# 11  88         Steve Jobs  1000000.0      M

# %% [markdown]
# ### Challenge. What rules does concatenate follows when it concatenates values?
# 1. It ignores the position of coulmns
# 2. It matches the names of the columns. If you have different name for the same column in different tables. It will match all columns apart of different name value and instead it will create one more column.

# %% [markdown]
# ### To test above said. Run the next lines of code.

# %%
# df = df.rename(columns={'EMP': 'Employee'})

# %%
# columns = df.columns.tolist()

# # Move the 'EMP' column to the desired position (position 3 in this case)
# columns.insert(3, columns.pop(columns.index('EMP')))

# # Reorder the DataFrame's columns
# df = df[columns]

# %% [markdown]
# ## Find the duplicates

# %%
df3.duplicated().sum()
# Out:
# 2

# %%
duplicates = df3.duplicated()

# %%
df3[duplicates]
# Out:
#    ID            EMP      PAY Gender
# 9  21  Kurt Hartmann  90000.0      M
# 0  19     Imran Khan  70000.0      M

# %% [markdown]
# ### Challenge: What happens if you have 3 same values within the dataset?

# %%
#We create a df with new row (In previous versions of Pandas we could have append the list to the end of the dataset now it is not possible anymore)
append = pd.DataFrame({'ID': [21], 'EMP': 'Kurt Hartmann', 'PAY': [90000], 'Gender': 'M'})
append
# Out:
#    ID            EMP    PAY Gender
# 0  21  Kurt Hartmann  90000      M

# %%
df3= pd.concat([df3,append],axis=0)

# %%
new_duplicates = df3.duplicated()

# %%
df3[new_duplicates]
# Out:
#    ID            EMP      PAY Gender
# 9  21  Kurt Hartmann  90000.0      M
# 0  19     Imran Khan  70000.0      M
# 0  21  Kurt Hartmann  90000.0      M

# %% [markdown]
# ### Answer to the Previous Challenge: duplicated() function returns you all duplicated values. If there are 3 identical values it would give you TRUE on 2 next values.

# %%
df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88ce1073d687> in <cell line: 1>()
# ----> 1 df3.head()
#
# NameError: name 'df3' is not defined

# %%
#Check df again
df3.head()
# Out:
#    ID              EMP       PAY Gender
# 0  11     Jack Johnson   20000.0      M
# 1  33      Karim Hikal  110000.0      M
# 2  12  Sonia Chiarelli   88000.0      F
# 3  22   Roberta Taylor       NaN      F
# 4  30  Stepan Zairovic   90000.0      M

# %%
df3.drop_duplicates(keep='first',inplace=True) #df3.drop_duplicates(subset='EMP',keep='first',inplace=True) in this case you say check in EMP column and drop

# %%
df3
# Out:
#     ID                EMP        PAY Gender
# 0   11       Jack Johnson    20000.0      M
# 1   33        Karim Hikal   110000.0      M
# 2   12    Sonia Chiarelli    88000.0      F
# 3   22     Roberta Taylor        NaN      F
# 4   30    Stepan Zairovic    90000.0      M
# 5    2      Samir Guliyev   100000.0      M
# 6   21      Kurt Hartmann    90000.0      M
# 7   19         Imran Khan    70000.0      M
# 8    9   Lorenzo Chillini    66000.0      M
# 11  72  Maria Ibrahimovic   120000.0      F
# 12  88         Steve Jobs  1000000.0      M

# %% [markdown]
# ## Rename the name of the column

# %%
df3.rename(columns={"PAY":"GROSS SALARY"},inplace= True)

# %%
df3.columns #This returns you the list of all columns.
# Out:
# Index(['ID', 'EMP', 'GROSS SALARY', 'Gender'], dtype='object')

# %% [markdown]
# ## Calculating the net salary after 23% of taxes!

# %%
df3['NET SALARY']= df3['GROSS SALARY']-df3['GROSS SALARY']*0.23

# %%
df3
# Out:
#    ID                EMP  GROSS SALARY Gender  NET SALARY
# 0  11       Jack Johnson       20000.0      M     15400.0
# 1  33        Karim Hikal      110000.0      M     84700.0
# 2  12    Sonia Chiarelli       88000.0      F     67760.0
# 3  22     Roberta Taylor           NaN      F         NaN
# 4  30    Stepan Zairovic       90000.0      M     69300.0
# 5   2      Samir Guliyev      100000.0      M     77000.0
# 6  21      Kurt Hartmann       90000.0      M     69300.0
# 7  19         Imran Khan       70000.0      M     53900.0
# 8   9   Lorenzo Chillini       66000.0      M     50820.0
# 1  72  Maria Ibrahimovic      120000.0      F     92400.0
# 2  88         Steve Jobs     1000000.0      M    770000.0
